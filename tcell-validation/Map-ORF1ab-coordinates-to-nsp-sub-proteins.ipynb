# %%
input_name = "2021-01-06-published-sars-cov2-tcell-epitopes.xlsx"
output_name = input_name.replace(".xlsx", "-corrected-protein-names.csv")
df = pd.read_excel(input_name)

# %%
print(len(df))
# Out:
# 973

# %%
df.Species.value_counts()
# Out:
# Human    958
# Mouse     15
# Name: Species, dtype: int64

# %%
orf1ab_nsp_to_seq = {}
last_id = None
buffer = []

def add_last_seq_and_clear_buffer():
    if last_id:
        orf1ab_nsp_to_seq[last_id] = "".join(buffer)
        buffer.clear()
    elif len(buffer) > 0:
        raise ValueError("Unexpected data in buffer")
        
with open("orf1ab-non-structural-proteins.fasta") as f:

    for l in f:
        if l.startswith(">"):
            add_last_seq_and_clear_buffer()
            last_id = l.split()[1]
        else:
            l = l.strip()
            if l:
                buffer.append(l)
    add_last_seq_and_clear_buffer()
orf1ab_nsp_to_len = {k: len(s) for k, s in orf1ab_nsp_to_seq.items()}
orf1ab_nsp_to_len
# Out:
# {'nsp1': 180,
#  'nsp2': 638,
#  'nsp3': 1945,
#  'nsp4': 500,
#  'nsp5': 306,
#  'nsp6': 290,
#  'nsp7': 83,
#  'nsp8': 198,
#  'nsp9': 113,
#  'nsp10': 139,
#  'nsp12': 932,
#  'nsp13': 601,
#  'nsp14': 527,
#  'nsp15': 346,
#  'nsp16': 298}

# %%
df.Protein.value_counts()
# Out:
# S         355
# nsp3      163
# N         127
# M          87
# ORF3a      55
# nsp12      55
# nsp4       45
# ORF1ab     38
# ORF8       20
# nsp16      11
# nsp6        5
# nsp13       5
# ORF7a       3
# ORF3        2
# ORF1a       1
# nsp7        1
# Name: Protein, dtype: int64

# %%
df[df.Protein == "ORF1a"]
# Out:
#        Source Species   Exposure          Assay Protein Start   End  Length  \
# 111  Schulien   Human  Infection  pMHC Multimer   ORF1a  2332  2340       9
#
#      # Responding  # Total  % Responding    Peptide      MHC  \
# 111          10.0     11.0      0.909091  ILFTRFFYV  A*02:01
#
#        Peptide Selection Method Allele Attribution Response type  \
# 111  Predicted Binding Affinity         Biological           CD8
#
#     T-cell Stimulation  Notes
# 111                NaN    NaN

# %%
total_ORF1ab_amino_acids = sum([n for n in orf1ab_nsp_to_len.values()])

# %%
total_ORF1ab_amino_acids
# Out:
# 7096

# %%
nsps_in_order = ["nsp%d" % (i + 1) for i in range(16) if i != 10]

# %%
ORF1ab_seq = "".join([orf1ab_nsp_to_seq[nsp_name] for nsp_name in nsps_in_order])

# %%
for _, row in df[df.Protein.str.startswith("ORF1a")].iterrows():
    start = row.Start
    end = row.End

# %%
ORF1ab_len = len(ORF1ab_seq)

# %%
base0_coord_to_nsp_name = [None] * ORF1ab_len
amino_acids_before_nsp = {}
last_pos = 0
for nsp_name in nsps_in_order:
    amino_acids_before_nsp[nsp_name] = last_pos
    n = orf1ab_nsp_to_len[nsp_name]
    for i in range(n):
        base0_coord_to_nsp_name[i + last_pos] = nsp_name
    last_pos += n

# %%
def drop_invisible_chars(s):
    s = s.strip()
    # strip out weird unicode spaces
    char_codes = [ord(c) for c in s]
    ascii_char_codes = [c for c in char_codes if c <= 128]
    chars = [chr(c) for c in ascii_char_codes]
    s_without_unicode = "".join(chars)
    if s != s_without_unicode:
        print("Converted %s (%d chars) => %s (%d chars)" % (
            s, len(s),
            s_without_unicode, len(s_without_unicode)))
    return s_without_unicode

def convert_string_to_number(s):
    if type(s) is int:
        return s
    elif type(s) is float:
        return int(s)
    else:
        assert type(s) is str
        s_without_unicode = drop_invisible_chars(s)
        return int(s_without_unicode)
        
rows = []
for row_num , row in df.iterrows():
    
    original_start = row.Start
    original_end = row.End
    original_protein = row.Protein
    start = convert_string_to_number(original_start)
    end = convert_string_to_number(original_end)
    protein = drop_invisible_chars(original_protein)
    row["Start"] = start
    row["End"] = end
    row["Protein"] = protein
    row["Original Location"] = "%s %s-%d" % (protein, start, end)
    if protein.startswith("nsp"):
        max_len = orf1ab_nsp_to_len[protein]
        if start >= max_len or end >= max_len:
            print("Row #%d has %s %d-%d but %s len = %d" % (
                    row_num + 1,
                    protein,
                    start,
                    end,
                    protein,
                    max_len
            ))
            protein = "ORF1ab"
        elif orf1ab_nsp_to_seq[protein][start - 1:end] != row.Peptide:
            print("Row #%d has wrong peptide ('%s') for %s %d-%d" % (
                    row_num + 1,
                    row.Peptide,
                    protein,
                    start,
                    end,
            ))
            protein = "ORF1ab"
    if protein.startswith("ORF1a"):
        nsp_name_of_start = base0_coord_to_nsp_name[start - 1]
        nsp_name_of_end = base0_coord_to_nsp_name[end - 1]
        row = row.copy()
        # make sure peptide matches ORF1ab reference if it has ORF1ab coordinates
        slice_peptide = ORF1ab_seq[start - 1:end]
        if row.Peptide != slice_peptide:
            raise ValueError("Wrong entry row #%d from %s (%s %d-%d), expected '%s' but got '%s'" % (
                row_num + 1,
                row.Source,
                protein,
                start,
                end,
                slice_peptide,
                row.Peptide))
       
        row["Protein"] = nsp_name_of_start
        row["Start"] = start - amino_acids_before_nsp[nsp_name_of_start]
        row["End"] = end - amino_acids_before_nsp[nsp_name_of_start]
    
    # make sure that peptide matches reference nsp proteins after remapping of coordinates
    if protein.startswith("nsp"):
        nsp_seq = orf1ab_nsp_to_seq[protein]
        slice_peptide = nsp_seq[row.Start - 1:row.End]
        peptide = row.Peptide
        if peptide != slice_peptide:
            raise ValueError("Wrong entry after mapping in row #%d from %s (%s %d-%d, originally %s), expected '%s' but got '%s'" % (
                row_num + 1,
                row.Source,
                row.Protein,
                row.Start,
                row.End,
                row["Original Location"],
                slice_peptide,
                row.Peptide,
                ))
    rows.append(row)

print("Processed %d records" % (len(rows),))

df_corrected = pd.DataFrame.from_records(rows)

# this column is incorrectly sometimes between [0,1] and other times between [0, 100]
df_corrected["% Responding"] = df_corrected["# Responding"] / df_corrected["# Total"]
# Out:
# Converted ​269 (4 chars) => 269 (3 chars)
# Converted ​919 (4 chars) => 919 (3 chars)
# Row #164 has wrong peptide ('HTTDPSFLGRY') for nsp3 1636-1646
# Row #165 has wrong peptide ('TTDPSFLGRYM') for nsp3 1637-1647
# Row #174 has wrong peptide ('ITFDNLKTL') for nsp3 1551-1559
# Row #180 has wrong peptide ('TDNYITTY') for nsp3 1322-1329
# Row #185 has nsp4 2898-2905 but nsp4 len = 500
# Row #186 has nsp4 3136-3144 but nsp4 len = 500
# Row #202 has nsp12 4586-4594 but nsp12 len = 932
# Row #203 has nsp12 5220-5229 but nsp12 len = 932
# Row #228 has nsp4 3155-3163 but nsp4 len = 500
# Row #229 has nsp16 6875-6886 but nsp16 len = 298
# Row #232 has nsp16 6913-6922 but nsp16 len = 298
# Row #234 has nsp4 3199-3207 but nsp4 len = 500
# Row #240 has nsp4 2788-2795 but nsp4 len = 500
# Row #241 has nsp3 2017-2028 but nsp3 len = 1945
# Row #242 has nsp12 4645-4657 but nsp12 len = 932
# Row #253 has wrong peptide ('TTDPSFLGRY') for nsp3 1637-1646
# Row #255 has nsp12 4892-4901 but nsp12 len = 932
# Row #257 has nsp3 2495-2504 but nsp3 len = 1945
# Row #258 has wrong peptide ('GELGDVRETMSYLF') for nsp3 1723-1736
# Row #261 has nsp4 2941-2949 but nsp4 len = 500
# Row #262 has nsp3 2305-2314 but nsp3 len = 1945
# Row #264 has nsp4 3219-3227 but nsp4 len = 500
# Row #265 has nsp12 5001-5010 but nsp12 len = 932
# Row #268 has nsp4 2960-2968 but nsp4 len = 500
# Row #269 has nsp3 2109-2117 but nsp3 len = 1945
# Row #271 has nsp16 7048-7056 but nsp16 len = 298
# Row #272 has nsp3 2664-2677 but nsp3 len = 1945
# Row #273 has nsp3 2089-2099 but nsp3 len = 1945
# Row #274 has nsp3 2086-2099 but nsp3 len = 1945
# Row #275 has wrong peptide ('FEPSTQYEY') for nsp3 941-949
# Row #276 has nsp12 4503-4511 but nsp12 len = 932
# Row #277 has nsp3 2332-2340 but nsp3 len = 1945
# Row #279 has wrong peptide ('KQEILGTVSW') for nsp3 1364-1373
# Row #280 has nsp4 3115-3124 but nsp4 len = 500
# Row #283 has nsp12 5299-5308 but nsp12 len = 932
# Row #287 has wrong peptide ('YTTTIKPVTY') for nsp3 1873-1882
# Row #288 has nsp4 3004-3012 but nsp4 len = 500
# Row #289 has nsp3 2389-2397 but nsp3 len = 1945
# Row #290 has nsp4 3060-3068 but nsp4 len = 500
# Row #292 has nsp3 2272-2281 but nsp3 len = 1945
# Row #293 has nsp3 2594-2602 but nsp3 len = 1945
# Row #295 has nsp4 3100-3107 but nsp4 len = 500
# Row #298 has nsp3 2435-2444 but nsp3 len = 1945
# Row #300 has nsp3 2585-2594 but nsp3 len = 1945
# Row #303 has nsp4 3196-3204 but nsp4 len = 500
# Row #306 has nsp3 2111-2119 but nsp3 len = 1945
# Row #307 has nsp4 2949-2957 but nsp4 len = 500
# Row #308 has nsp3 2680-2688 but nsp3 len = 1945
# Row #309 has wrong peptide ('SEYKGPITDVFY') for nsp3 1857-1868
# Row #313 has wrong peptide ('DTVIEVQGYK') for nsp3 828-837
# Row #314 has nsp3 1966-1975 but nsp3 len = 1945
# Row #319 has wrong peptide ('MSALNHTKK') for nsp3 1647-1655
# Row #323 has wrong peptide ('IEVNSFSGY') for nsp3 1023-1031
# Row #324 has nsp3 2132-2141 but nsp3 len = 1945
# Row #325 has nsp3 2325-2333 but nsp3 len = 1945
# Row #327 has nsp16 7033-7042 but nsp16 len = 298
# Row #328 has nsp3 2582-2590 but nsp3 len = 1945
# Row #329 has nsp4 2884-2892 but nsp4 len = 500
# Row #330 has nsp3 2201-2209 but nsp3 len = 1945
# Row #331 has nsp3 2254-2262 but nsp3 len = 1945
# Row #337 has nsp12 4733-4741 but nsp12 len = 932
# Row #338 has wrong peptide ('TISLAGSYK') for nsp3 1504-1512
# Row #342 has wrong peptide ('ISLAGSYKDW') for nsp3 1505-1514
# Row #343 has wrong peptide ('EIDPKLDNY') for nsp3 1891-1899
# Row #344 has nsp3 2618-2626 but nsp3 len = 1945
# Row #346 has wrong peptide ('SEYTGNYQCGHY') for nsp3 1825-1836
# Row #352 has nsp3 2323-2331 but nsp3 len = 1945
# Row #355 has wrong peptide ('KENSYTTTIKPVTY') for nsp3 1869-1882
# Row #356 has nsp3 2189-2197 but nsp3 len = 1945
# Row #358 has nsp3 2318-2327 but nsp3 len = 1945
# Row #359 has nsp3 2191-2199 but nsp3 len = 1945
# Row #363 has nsp3 2246-2254 but nsp3 len = 1945
# Row #364 has wrong peptide ('VEVQPQLEM') for nsp3 1006-1014
# Row #370 has nsp3 2513-2521 but nsp3 len = 1945
# Row #371 has nsp12 4998-5009 but nsp12 len = 932
# Row #373 has nsp3 2456-2464 but nsp3 len = 1945
# Row #374 has nsp3 2550-2560 but nsp3 len = 1945
# Row #377 has nsp12 4971-4979 but nsp12 len = 932
# Row #383 has nsp12 5221-5230 but nsp12 len = 932
# Row #386 has nsp12 4938-4947 but nsp12 len = 932
# Row #387 has wrong peptide ('FELDERIDKVL') for nsp3 843-853
# Row #389 has nsp3 2192-2200 but nsp3 len = 1945
# Row #392 has wrong peptide ('QVVDMSMTY') for nsp3 1582-1590
# Row #393 has wrong peptide ('MLAHAEETR') for nsp3 1378-1386
# Row #394 has wrong peptide ('DVFYKENSY') for nsp3 1865-1873
# Row #398 has wrong peptide ('HTTDPSFLGR') for nsp3 1636-1645
# Row #400 has nsp3 2616-2624 but nsp3 len = 1945
# Row #401 has nsp12 4558-4566 but nsp12 len = 932
# Row #402 has wrong peptide ('YENFNQHEV') for nsp3 1135-1143
# Row #403 has wrong peptide ('EAKKVKPTV') for nsp3 1048-1056
# Row #410 has nsp12 5193-5204 but nsp12 len = 932
# Row #416 has wrong peptide ('LVSDIDITF') for nsp3 1270-1278
# Row #423 has nsp12 4840-4849 but nsp12 len = 932
# Row #425 has nsp3 2584-2591 but nsp3 len = 1945
# Row #427 has wrong peptide ('KQEILGTVSW') for nsp3 1364-1373
# Row #428 has nsp3 1951-1959 but nsp3 len = 1945
# Row #429 has nsp3 2088-2099 but nsp3 len = 1945
# Row #435 has nsp3 2468-2477 but nsp3 len = 1945
# Row #437 has wrong peptide ('GADPIHSLR') for nsp3 1155-1163
# Row #438 has wrong peptide ('LTAVVIPTK') for nsp3 1296-1304
# Row #439 has wrong peptide ('VVVNAANVY') for nsp3 1056-1064
# Row #454 has wrong peptide ('LEMELTPVV') for nsp3 1012-1020
# Row #455 has nsp3 2749-2757 but nsp3 len = 1945
# Row #456 has nsp12 5025-5033 but nsp12 len = 932
# Row #458 has nsp12 5315-5323 but nsp12 len = 932
# Row #460 has nsp3 2136-2145 but nsp3 len = 1945
# Row #463 has nsp12 4814-4822 but nsp12 len = 932
# Row #470 has nsp12 5308-5316 but nsp12 len = 932
# Row #472 has nsp12 4800-4809 but nsp12 len = 932
# Row #473 has wrong peptide ('VELGTEVNEF') for nsp3 862-871
# Row #474 has wrong peptide ('SELLTPLGI') for nsp3 887-895
# Row #476 has nsp3 2268-2276 but nsp3 len = 1945
# Row #478 has nsp3 1999-2008 but nsp3 len = 1945
# Row #481 has nsp12 5217-5229 but nsp12 len = 932
# Row #485 has nsp12 4810-4822 but nsp12 len = 932
# Row #486 has wrong peptide ('APYIVGDVV') for nsp3 1283-1291
# Row #492 has nsp3 2593-2602 but nsp3 len = 1945
# Row #494 has wrong peptide ('QEILGTVSW') for nsp3 1365-1373
# Row #495 has wrong peptide ('ESKPSVEQR') for nsp3 1217-1225
# Row #497 has nsp3 2194-2203 but nsp3 len = 1945
# Row #499 has nsp4 2804-2812 but nsp4 len = 500
# Row #502 has nsp3 2616-2624 but nsp3 len = 1945
# Row #504 has nsp3 2604-2612 but nsp3 len = 1945
# Row #506 has nsp12 5219-5229 but nsp12 len = 932
# Row #507 has nsp4 3131-3139 but nsp4 len = 500
# Row #508 has nsp12 4920-4928 but nsp12 len = 932
# Row #509 has wrong peptide ('RTNVYLAVF') for nsp3 1170-1178
# Row #510 has nsp12 4732-4741 but nsp12 len = 932
# Row #511 has nsp12 5024-5032 but nsp12 len = 932
# Row #512 has nsp3 2030-2039 but nsp3 len = 1945
# Row #513 has nsp3 2704-2713 but nsp3 len = 1945
# Row #515 has nsp12 4953-4961 but nsp12 len = 932
# Row #518 has nsp4 3122-3130 but nsp4 len = 500
# Row #519 has nsp3 2167-2175 but nsp3 len = 1945
# Row #520 has nsp12 4533-4541 but nsp12 len = 932
# Row #522 has nsp12 5318-5326 but nsp12 len = 932
# Row #524 has nsp16 7020-7028 but nsp16 len = 298
# Row #526 has nsp3 2049-2057 but nsp3 len = 1945
# Row #528 has nsp6 3666-3674 but nsp6 len = 290
# Row #531 has nsp12 4433-4442 but nsp12 len = 932
# Row #534 has nsp3 2098-2107 but nsp3 len = 1945
# Row #535 has wrong peptide ('YIATNGPLK') for nsp3 1090-1098
# Row #536 has nsp4 2875-2884 but nsp4 len = 500
# Row #539 has wrong peptide ('ITDVFYKENSY') for nsp3 1863-1873
# Row #542 has wrong peptide ('YMSALNHTK') for nsp3 1646-1654
# Row #543 has nsp3 2325-2334 but nsp3 len = 1945
# Row #547 has nsp3 2254-2262 but nsp3 len = 1945
# Row #548 has wrong peptide ('MELTPVVQTI') for nsp3 1014-1023
# Row #552 has nsp12 4977-4985 but nsp12 len = 932
# Row #553 has nsp12 4558-4567 but nsp12 len = 932
# Row #554 has wrong peptide ('LEFGATSAAL') for nsp3 960-969
# Row #555 has nsp3 2111-2119 but nsp3 len = 1945
# Row #557 has nsp3 2323-2331 but nsp3 len = 1945
# Row #559 has wrong peptide ('SALNHTKKW') for nsp3 1648-1656
# Row #561 has nsp12 4841-4849 but nsp12 len = 932
# Row #562 has nsp3 2169-2176 but nsp3 len = 1945
# Row #564 has nsp3 2469-2477 but nsp3 len = 1945
# Row #565 has nsp4 2864-2872 but nsp4 len = 500
# Row #568 has wrong peptide ('YPQVNGLTSI') for nsp3 1658-1667
# Row #569 has wrong peptide ('TEIDPKLDNYY') for nsp3 1890-1900
# Row #571 has nsp4 2854-2862 but nsp4 len = 500
# Row #573 has wrong peptide ('EVKPFITESK') for nsp3 1210-1219
# Row #583 has nsp3 1951-1959 but nsp3 len = 1945
# Row #584 has wrong peptide ('ASFDNFKFV') for nsp3 1923-1931
# Row #585 has wrong peptide ('VSSPDAVTAY') for nsp3 1477-1486
# Row #587 has nsp16 7014-7026 but nsp16 len = 298
# Row #590 has nsp6 3653-3661 but nsp6 len = 290
# Row #592 has nsp6 3605-3613 but nsp6 len = 290
# Row #595 has nsp3 2355-2363 but nsp3 len = 1945
# Row #596 has nsp3 2384-2392 but nsp3 len = 1945
# Row #599 has nsp4 3108-3116 but nsp4 len = 500
# Row #600 has nsp3 2753-2761 but nsp3 len = 1945
# Row #601 has nsp3 1971-1979 but nsp3 len = 1945
# Row #603 has nsp12 4557-4566 but nsp12 len = 932
# Row #604 has wrong peptide ('YYKKDNSYF') for nsp3 1899-1907
# Row #605 has nsp3 2330-2337 but nsp3 len = 1945
# Row #606 has nsp3 1967-1975 but nsp3 len = 1945
# Row #607 has wrong peptide ('MSALNHTKKW') for nsp3 1647-1656
# Row #608 has nsp3 2196-2204 but nsp3 len = 1945
# Row #617 has wrong peptide ('MSMTYGQQF') for nsp3 1586-1594
# Row #618 has wrong peptide ('VVDYGARFY') for nsp3 1415-1423
# Row #619 has nsp12 5267-5276 but nsp12 len = 932
# Row #620 has nsp3 2553-2561 but nsp3 len = 1945
# Row #621 has nsp6 3655-3663 but nsp6 len = 290
# Row #624 has nsp3 2589-2598 but nsp3 len = 1945
# Row #625 has nsp3 1937-1947 but nsp3 len = 1945
# Row #626 has nsp3 2242-2250 but nsp3 len = 1945
# Row #627 has nsp12 4892-4900 but nsp12 len = 932
# Row #628 has nsp3 2494-2504 but nsp3 len = 1945
# Row #629 has nsp3 2625-2633 but nsp3 len = 1945
# Row #631 has nsp4 3148-3155 but nsp4 len = 500
# Row #632 has nsp3 2273-2281 but nsp3 len = 1945
# Row #635 has nsp3 2208-2217 but nsp3 len = 1945
# Row #636 has wrong peptide ('TSNPTTFHL') for nsp3 1538-1546
# Row #638 has wrong peptide ('VMYMGTLSY') for nsp3 1768-1776
# Row #639 has nsp4 2885-2892 but nsp4 len = 500
# Row #640 has nsp4 3101-3108 but nsp4 len = 500
# Row #641 has nsp3 2660-2673 but nsp3 len = 1945
# Row #643 has nsp4 3071-3080 but nsp4 len = 500
# Row #646 has wrong peptide ('AIVSTIQRK') for nsp3 1397-1405
# Row #648 has nsp16 6980-6988 but nsp16 len = 298
# Row #651 has nsp3 2552-2560 but nsp3 len = 1945
# Row #652 has wrong peptide ('YLATALLTL') for nsp3 1675-1683
# Row #654 has nsp3 2273-2281 but nsp3 len = 1945
# Row #655 has nsp3 2435-2444 but nsp3 len = 1945
# Row #656 has nsp12 4710-4718 but nsp12 len = 932
# Row #657 has nsp3 2225-2233 but nsp3 len = 1945
# Row #659 has nsp4 2936-2945 but nsp4 len = 500
# Row #660 has wrong peptide ('EIDPKLDNY') for nsp3 1891-1899
# Row #663 has nsp12 4433-4441 but nsp12 len = 932
# Row #664 has nsp4 2924-2932 but nsp4 len = 500
# Row #666 has wrong peptide ('LYDKLVSSF') for nsp3 1182-1190
# Row #673 has nsp12 5133-5142 but nsp12 len = 932
# Row #675 has nsp4 3022-3030 but nsp4 len = 500
# Row #676 has nsp16 6807-6815 but nsp16 len = 298
# Row #678 has nsp6 3612-3621 but nsp6 len = 290
# Row #681 has wrong peptide ('FELDERIDKV') for nsp3 843-852
# Row #703 has nsp12 5246-5260 but nsp12 len = 932
# Row #709 has nsp16 7056-7070 but nsp16 len = 298
# Row #710 has nsp16 7061-7075 but nsp16 len = 298
# Row #711 has nsp16 7081-7095 but nsp16 len = 298
# Row #755 has wrong peptide ('TLRVEAFEYYHTTDP') for nsp3 1626-1640
# Row #756 has wrong peptide ('HTTDPSFLGRYMSAL') for nsp3 1636-1650
# Row #770 has nsp4 3111-3125 but nsp4 len = 500
# Row #781 has nsp3 1946-1960 but nsp3 len = 1945
# Row #782 has nsp3 1951-1965 but nsp3 len = 1945
# Row #783 has nsp3 1956-1970 but nsp3 len = 1945
# Row #784 has nsp3 1961-1975 but nsp3 len = 1945
# Row #785 has nsp4 3206-3220 but nsp4 len = 500
# Row #793 has nsp12 5251-5265 but nsp12 len = 932
# Row #794 has nsp12 5256-5270 but nsp12 len = 932
# Row #833 has wrong peptide ('LPNDDTLRVEAFEYY') for nsp3 1621-1635
# Row #834 has wrong peptide ('SFLGRYMSALNHTKK') for nsp3 1641-1655
# Row #835 has wrong peptide ('YMSALNHTKKWKYPQ') for nsp3 1646-1660
# Row #836 has wrong peptide ('NHTKKWKYPQVNGLT') for nsp3 1651-1665
# Row #837 has nsp4 2856-2870 but nsp4 len = 500
# Row #838 has nsp4 2866-2880 but nsp4 len = 500
# Row #839 has nsp4 2881-2895 but nsp4 len = 500
# Row #840 has nsp4 3046-3060 but nsp4 len = 500
# Row #887 has wrong peptide ('ADAVIKTLQPVSELL') for nsp3 876-890
# Row #888 has wrong peptide ('ESDDYIATNGPLKVG') for nsp3 1086-1100
# Row #889 has wrong peptide ('IATNGPLKVGGSCVL') for nsp3 1091-1105
# Row #890 has wrong peptide ('SGHNLAKHCLHVVGP') for nsp3 1106-1120
# Row #892 has wrong peptide ('NLYDKLVSSFLEMKS') for nsp3 1181-1195
# Row #894 has wrong peptide ('RFYFYTSKTTVASLI') for nsp3 1421-1435
# Row #895 has nsp3 1941-1955 but nsp3 len = 1945
# Row #896 has nsp3 1976-1990 but nsp3 len = 1945
# Row #897 has nsp3 1991-2005 but nsp3 len = 1945
# Row #898 has nsp3 2181-2195 but nsp3 len = 1945
# Row #899 has nsp3 2186-2200 but nsp3 len = 1945
# Row #900 has nsp3 2201-2215 but nsp3 len = 1945
# Row #901 has nsp3 2221-2235 but nsp3 len = 1945
# Row #902 has nsp3 2316-2330 but nsp3 len = 1945
# Row #903 has nsp3 2321-2335 but nsp3 len = 1945
# Row #904 has nsp4 3096-3110 but nsp4 len = 500
# Row #905 has nsp4 3121-3135 but nsp4 len = 500
# Row #906 has nsp4 3126-3140 but nsp4 len = 500
# Row #907 has nsp4 3131-3145 but nsp4 len = 500
# Row #908 has nsp4 3151-3165 but nsp4 len = 500
# Row #909 has nsp4 3201-3215 but nsp4 len = 500
# Row #910 has nsp4 3226-3240 but nsp4 len = 500
# Row #911 has nsp4 3231-3245 but nsp4 len = 500
# Row #912 has nsp4 3241-3255 but nsp4 len = 500
# Row #913 has nsp4 3246-3260 but nsp4 len = 500
# Row #914 has nsp13 5486-5500 but nsp13 len = 601
# Row #915 has nsp13 5496-5510 but nsp13 len = 601
# Row #916 has nsp13 5506-5520 but nsp13 len = 601
# Row #917 has nsp13 5511-5525 but nsp13 len = 601
# Row #918 has nsp13 5711-5725 but nsp13 len = 601
# Row #949 has wrong peptide ('YCIDGALLTKSSEYK') for nsp3 1846-1860
# Row #950 has nsp3 2096-2110 but nsp3 len = 1945
# Row #951 has nsp12 4701-4715 but nsp12 len = 932
# Row #952 has nsp12 4706-4720 but nsp12 len = 932
# Row #953 has nsp12 5011-5025 but nsp12 len = 932
# Row #954 has nsp12 5016-5030 but nsp12 len = 932
# Row #955 has nsp12 5091-5105 but nsp12 len = 932
# Row #956 has nsp12 5241-5255 but nsp12 len = 932
# Row #957 has nsp12 5271-5285 but nsp12 len = 932
# Row #961 has nsp12 4916-4930 but nsp12 len = 932
# Row #962 has nsp12 4966-4980 but nsp12 len = 932
# Row #963 has nsp12 4971-4985 but nsp12 len = 932
# Row #964 has nsp12 5041-5055 but nsp12 len = 932
# Row #965 has nsp12 5056-5070 but nsp12 len = 932
# Row #966 has nsp12 5086-5100 but nsp12 len = 932
# Processed 973 records

# %%
df_corrected.to_csv(output_name, index=False)

# %%
df_corrected["Protein"].value_counts()
# Out:
# S        355
# nsp3     177
# N        127
# M         87
# nsp12     58
# ORF3a     55
# nsp4      47
# ORF8      20
# nsp16     11
# nsp13     10
# nsp6       6
# nsp2       4
# nsp9       4
# nsp8       3
# ORF7a      3
# nsp7       2
# ORF3       2
# nsp14      1
# nsp5       1
# Name: Protein, dtype: int64

# %%
window_size = 10
rounded_start = ((df_corrected["Start"].map(int) / window_size).map(int) * window_size)
(df_corrected["Protein"] + "-" + rounded_start.map(str)).value_counts()[:20]
# Out:
# N-320        14
# N-100        13
# S-1200       11
# M-170        10
# N-360         9
# ORF3a-200     8
# N-310         8
# S-260         8
# S-710         8
# nsp3-810      8
# S-1050        8
# S-860         8
# S-680         7
# M-130         7
# S-160         7
# S-440         7
# N-300         7
# S-30          7
# S-370         6
# nsp3-1500     6
# dtype: int64

# %%
df_corrected[df.Species== "Human"].Source.value_counts()
# Out:
# Tarke          803
# Peng            46
# Schulien        36
# Ferretti        29
# Nelde           17
# Shomuradova     13
# Le Bert          8
# Chour            2
# Snyder           2
# Minervina        2
# Name: Source, dtype: int64
